# %% [markdown]
# # Veri Görselleştirme
# * MATPLOTLIP & SEABORN

# %% [markdown]
# ### Matplotlib
#
# * low level veri görselleştirme aracıdır seaborna göre
# * diğer kütüphanelerle entegre

# %% [markdown]
# ### Hangi görselleştirmeye nasıl bir görselleştirme yapmalıyım
#
# * Kategorik Değişken : sütun grafik . countplot bar
# * Sayısal Değişken : histogram , boxplot

# %% [markdown]
# ### Kategorik Değişken Görselleştirme

# %%
import pandas as pd 
import seaborn as sns  
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns',None)
df = sns.load_dataset("titanic") 
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["sex"].value_counts().plot(kind = "bar") 
plt.show()

# %% [markdown]
# ### Sayısal Değişken Görselleştirme

# %%
plt.hist(df["age"]) 
plt.show()

# %%
plt.boxplot(df["fare"]) 
plt.show()

# %% [markdown]
# ### Matplotlib'in Özellikleri

# %%
# Plot 

x = np.array([1,8]) 
y = np.array([0,150]) 

plt.plot(x,y) 
plt.show()

# %%
x = np.array([1,8]) 
y = np.array([0,150]) 

plt.plot(x,y , "o") 
plt.show()

# %%
a = np.array([2, 4, 6, 8, 10]) 
b = np.array([1 , 3 , 5 , 7, 9]) 

plt.plot(a,b,"o") 
plt.show()

# %%
# marker : işaretleyici 

y = np.array([13,28,11,100]) 

plt.plot(y , marker= 'o') 
plt.show()

# %%
# line : çizgi özelliği 

y = np.array([13,28,11,100])  
plt.plot(y, linestyle = "dashed") 
plt.show()

# %%
y = np.array([13,28,11,100])  
plt.plot(y, linestyle = "dotted") 
plt.show()

# %%
y = np.array([13,28,11,100])  
plt.plot(y, linestyle = "dashdot") 
plt.show()

# %%
# color 

y = np.array([13,28,11,100])  
plt.plot(y, linestyle = "dashdot",color = "r") 
plt.show()

# %%
# multiple lines 

x = np.array([23,15,32,10])
y = np.array([13,28,11,100])  
plt.plot(x)
plt.plot(y) 
plt.show()

# %%
# Labels 

x = np.array([23,15,32,100])
y = np.array([13,28,11,10])   

plt.plot(x,y) 
plt.show() 

#başlık 
plt.title("Bu ana başlık")  

# x eksenini isimlendirme 
plt.xlabel("x ekseni ismi") 

# y ekseni isimlendirme 
plt.ylabel("y ekseni ismi") 

# ızgara ekleme okunurluğu artması için 
plt.grid()
plt.show()

# %%
# subplots : birden fazla grafik gösterimi 1x2 lik grafik
# plot 1 
x = np.array([23,15,32,100])
y = np.array([13,28,11,10])    
plt.subplot(1,2,1) 
plt.title("1")  
plt.grid()
plt.plot(x,y) 


# plot 2 
x = np.array([23,15,32,100])
y = np.array([13,28,11,10])    
plt.subplot(1,2,2) 
plt.title("2")  
plt.grid()
plt.plot(x,y)

# %%
#1x3 luk 
# plot 1 
x = np.array([23,15,32,100])
y = np.array([13,28,11,10])    
plt.subplot(1,3,1) 
plt.title("1")  
plt.grid()
plt.plot(x,y) 


# plot 2 
x = np.array([23,15,32,100])
y = np.array([13,28,11,10])    
plt.subplot(1,3,2) 
plt.title("2")  
plt.grid()
plt.plot(x,y)  

x = np.array([23,15,32,100])
y = np.array([13,28,11,10])    
plt.subplot(1,3,3) 
plt.title("3")  
plt.grid()
plt.plot(x,y)

# %% [markdown]
# ### Seaborn ile Veri Görselleştirme
#
# * yüksek seviyeli, daha az eforla daha çok iş yapar

# %%
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
df = sns.load_dataset("tips") 
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Kategorik , sütun

df["sex"].value_counts()
sns.countplot(x = df["sex"], data=df) 
plt.show()

# %%
# sayısal değişken ,boxplot,histogram 

# boxplot
sns.boxplot(x = df["total_bill"]) 
plt.show() 

# hist 
df["total_bill"].hist() 
plt.show()
